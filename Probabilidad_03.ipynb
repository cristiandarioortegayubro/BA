# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/BA/blob/main/Probabilidad_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo](https://github.com/cristiandarioortegayubro/BA/blob/main/dba.png?raw=true)

# %% [markdown]
# ![logo](https://www.python.org/static/community_logos/python-powered-h-70x91.png)

# %% [markdown]
# <p>
# <font color="DarkBlue">
#
# **Este cuaderno tiene por objeto generar Dataframes de datos simulados en base a las distribuciones de probabilidad vistas.**
#
# </font>
# </p>

# %% [markdown]
# ## **<font color="DarkBlue">Dummy Data Sets</font>**

# %%
import pandas as pd
import numpy as np
import scipy.stats as ss

data =pd.DataFrame(
    {
        "A": np.random.randn(1000),
        "B": np.random.normal(5, 3, 1000),
        "C": np.random.uniform(5, 32, 1000)
    }
)
data.head()
# Out:
#           A         B          C
# 0  0.096408  3.786288   6.075517
# 1  0.955131  0.762347  12.078267
# 2 -0.263529  1.220002  28.555608
# 3 -0.477219  9.053791  31.151746
# 4 -0.249577  1.150764   6.782727
#           A         B          C
# 0  0.498650  4.773721  26.610976
# 1 -2.946890  7.206964  27.742802
# 2  0.160623  1.045396  11.677113
# 3  0.272531  6.393660  28.593017
# 4 -0.248601  5.839353   7.152213

# %%
data.describe()
# Out:
#                  A            B            C
# count  1000.000000  1000.000000  1000.000000
# mean     -0.010834     5.028903    19.229790
# std       1.005068     3.046639     7.851755
# min      -3.148006    -6.353424     5.001313
# 25%      -0.705234     3.018256    12.766850
# 50%      -0.026108     5.031596    19.750195
# 75%       0.688980     7.105990    25.997543
# max       3.399105    14.167277    31.992141

# %%
import plotly.express as px

# %%
px.histogram(data.A)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(data.B)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(data.C)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/cristiandarioortegayubro/UNI/main/clientes01.csv')
df.head()
# Out:
#    ID  Trabajo  Edad  Salario  Compra
# 0   0        1    19    19000       0
# 1   1        1    35    20000       0
# 2   2        0    26    43000       0
# 3   3        0    27    57000       0
# 4   4        1    19    76000       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       400 non-null    int64
#  1   Trabajo  400 non-null    int64
#  2   Edad     400 non-null    int64
#  3   Salario  400 non-null    int64
#  4   Compra   400 non-null    int64
# dtypes: int64(5)
# memory usage: 15.8 KB

# %%
df["Datos simulados"] = np.random.randn(len(df))

# %%
df
# Out:
#       ID  Trabajo  Edad  Salario  Compra  Datos simulados
# 0      0        1    19    19000       0        -0.209406
# 1      1        1    35    20000       0        -0.118709
# 2      2        0    26    43000       0        -0.951954
# 3      3        0    27    57000       0        -0.431758
# 4      4        1    19    76000       0        -0.499442
# ..   ...      ...   ...      ...     ...              ...
# 395  395        0    46    41000       1         1.989643
# 396  396        1    51    23000       1        -0.284918
# 397  397        0    50    20000       1         0.737070
# 398  398        1    36    33000       0        -1.109597
# 399  399        0    49    36000       1         1.178626
#
# [400 rows x 6 columns]

# %%
df["Datos simulados"].describe()
# Out:
# count    400.000000
# mean       0.054164
# std        0.984275
# min       -2.969813
# 25%       -0.551701
# 50%        0.042177
# 75%        0.693397
# max        2.714933
# Name: Datos simulados, dtype: float64

# %%
np.percentile(df["Datos simulados"], 50)
# Out:
# 0.04217733814707694
