# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/BA/blob/main/pd_ej_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo](https://github.com/cristiandarioortegayubro/BA/blob/main/dba.png?raw=true)

# %% [markdown]
# ![pandas](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/250px-Pandas_logo.svg.png)

# %% [markdown]
# <h1><b>
# Ejercicio de práctica para empezar a usar Pandas...

# %% [markdown]
# ***Ejecutado el siguiente script...***

# %%
archivo = "https://raw.githubusercontent.com/cristiandarioortegayubro/BA/main/Datasets/Analisis_de_Facturas_de_Venta.csv"

# %% [markdown]
# ***...y teniendo en cuenta el siguiente material soporte...***

# %% [markdown]
# [Material soporte de Pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html)

# %% [markdown]
# ## **Punto 01 - Active los módulos necesarios**
#
# <a href="#respuesta01">Respuesta sugerida</a>

# %%
# active los módulos necesarios para generar un dataframe

# %% [markdown]
# ## **Punto 02 - Creando el DataFrame con el "archivo"**
#
# - Creando el DataFrame
# - Visualizándolo
# - Propiedades del DataFrame
# - Información del DataFrame
#
# <a href="#respuesta02">Respuesta sugerida</a>

# %%
# genere el DataFrame

# %%
# visualice las primeros 6 filas

# %%
# visualice las últimas 9 filas

# %%
# Propiedades dimensiones del DataFrame (filas y columnas)

# %% [markdown]
# ## **Punto 03 - Obteniendo información del DataFrame**
#
# ~~~python
# Función info()
# ~~~
# ~~~Python
# Función describe()
# ~~~
#
# <a href="#respuesta03">Respuesta sugerida</a>

# %%
# Obtenga información acerca del tipo de datos del DataFrame, los nombres de las columnas y la cantidad de datos no nulos

# %%
# Obtenga información descriptiva del DataFrame

# %% [markdown]
# ## **Punto 04 - Si algún tipo de datos no es el que corresponde, cambielo...**
#
# <a href="#respuesta04">Respuesta sugerida</a>

# %%
# Verifique los tipos de datos, si alguno no corresponde, cambielo por el correcto...

# %% [markdown]
# ## **Punto 05 - Agrupe el DataFrame...**
#
# ~~~Python
# Función groupby()
# ~~~
#
# <a href="#respuesta05">Respuesta sugerida</a>

# %%
# Agrupe el DataFrame por Organización, para determinar la cantidad total de productos comprados y el importe total de transacción...

# %% [markdown]
# ## **Punto 06 - Agrupe el DataFrame...**
#
# ~~~Python
# Función groupby()
# ~~~
#
# <a href="#respuesta06">Respuesta sugerida</a>

# %%
# Ahora por Organización y por Fecha...

# %% [markdown]
# <a name="respuesta01"></a>
#
# ## **Respuesta sugerida al Punto 01 - Generación de variables numéricas**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <a name="respuesta02"></a>
#
# ## **Respuesta sugerida al Punto 02 - Creando el DataFrame con los "datos"**

# %%
df = pd.read_csv(archivo)
df
# Out:
#            DOCUMENTO       ORGANIZACION     FECHA TIPOFACTURA  \
# 0    B-0001-00000102       Etigand S.A.  27/12/19     Factura
# 1    B-0001-00000101      Javier Moroni  21/12/19     Factura
# 2    A-0001-00000231       Amazon Group  10/12/19     Factura
# 3    A-0001-00000230       Amazon Group   6/12/19     Factura
# 4    A-0001-00000229   Manganello S.R.L  20/11/19     Factura
# ..               ...                ...       ...         ...
# 154  A-0001-00000128     Hernandez S.A.   31/1/18     Factura
# 155  B-0001-00000069       Etigand S.A.   25/1/18     Factura
# 156  B-0001-00000069       Etigand S.A.   25/1/18     Factura
# 157  B-0001-00000068  Ferrari Hnos S.A.    1/1/18     Factura
# 158  B-0001-00000068  Ferrari Hnos S.A.    1/1/18     Factura
#
#                     PRODUCTO  CANTIDAD      PRECIO  IMPORTEMONTRANSACCION  \
# 0            Consultoria Web      50.0   5785.1240              289256.20
# ...

# %%
df.head(6)
# Out:
#          DOCUMENTO      ORGANIZACION     FECHA TIPOFACTURA  \
# 0  B-0001-00000102      Etigand S.A.  27/12/19     Factura
# 1  B-0001-00000101     Javier Moroni  21/12/19     Factura
# 2  A-0001-00000231      Amazon Group  10/12/19     Factura
# 3  A-0001-00000230      Amazon Group   6/12/19     Factura
# 4  A-0001-00000229  Manganello S.R.L  20/11/19     Factura
# 5  A-0001-00000228     Galardon S.A.  17/11/19     Factura
#
#                   PRODUCTO  CANTIDAD      PRECIO  IMPORTEMONTRANSACCION  \
# 0          Consultoria Web      50.0   5785.1240              289256.20
# 1               Honorarios       1.0  99586.7769               99586.78
# 2        Parlantes para PC      30.0   1990.0000               59700.00
# 3    Mercaderia de Reventa      30.0  10358.0000              310740.00
# 4          Consultoria Web      50.0   6300.0000              315000.00
# 5  Impresora Multifuncion       23.0  10209.0000              234807.00
#
#              MONEDA
# 0  Pesos Argentinos
# ...

# %%
df.tail(9)
# Out:
#            DOCUMENTO       ORGANIZACION    FECHA TIPOFACTURA  \
# 150  A-0001-00000131   Ignition S.A.C.I  21/2/18     Factura
# 151  A-0001-00000130     Horizonte S.A.  15/2/18     Factura
# 152  B-0001-00000070       Etigand S.A.  10/2/18     Factura
# 153  A-0001-00000129       Berker S.R.L   2/2/18     Factura
# 154  A-0001-00000128     Hernandez S.A.  31/1/18     Factura
# 155  B-0001-00000069       Etigand S.A.  25/1/18     Factura
# 156  B-0001-00000069       Etigand S.A.  25/1/18     Factura
# 157  B-0001-00000068  Ferrari Hnos S.A.   1/1/18     Factura
# 158  B-0001-00000068  Ferrari Hnos S.A.   1/1/18     Factura
#
#                     PRODUCTO  CANTIDAD      PRECIO  IMPORTEMONTRANSACCION  \
# 150          Consultoria Web       1.0   2500.0000                2500.00
# 151          Consultoria Web       1.0  25800.0000               25800.00
# 152      Consultoria Digital       1.0   2500.0000                2500.00
# ...

# %%
df.shape
# Out:
# (159, 9)

# %% [markdown]
# <a name="respuesta03"></a>
#
# ## **Respuesta sugerida al Punto 03 - Obteniendo información del DataFrame**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DOCUMENTO              159 non-null    object
#  1   ORGANIZACION           159 non-null    object
#  2   FECHA                  159 non-null    object
#  3   TIPOFACTURA            159 non-null    object
#  4   PRODUCTO               159 non-null    object
#  5   CANTIDAD               159 non-null    float64
#  6   PRECIO                 159 non-null    float64
#  7   IMPORTEMONTRANSACCION  159 non-null    float64
#  8   MONEDA                 159 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 11.3+ KB

# %%
df.describe()
# Out:
#          CANTIDAD         PRECIO  IMPORTEMONTRANSACCION
# count  159.000000     159.000000             159.000000
# mean     7.383648   24021.195378           58406.882767
# std     11.455914   30051.944155           73240.581780
# min      1.000000     107.438000             123.970000
# 25%      1.000000    3500.000000           14525.000000
# 50%      1.000000   12000.000000           31404.960000
# 75%     10.000000   32249.500000           71570.250000
# max     60.000000  165980.000000          370620.000000

# %% [markdown]
# <a name="respuesta04"></a>
#
# ## **Respuesta sugerida al Punto 04 - Cambiando el tipo de datos**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DOCUMENTO              159 non-null    object
#  1   ORGANIZACION           159 non-null    object
#  2   FECHA                  159 non-null    object
#  3   TIPOFACTURA            159 non-null    object
#  4   PRODUCTO               159 non-null    object
#  5   CANTIDAD               159 non-null    float64
#  6   PRECIO                 159 non-null    float64
#  7   IMPORTEMONTRANSACCION  159 non-null    float64
#  8   MONEDA                 159 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 11.3+ KB

# %%
df["FECHA"] = pd.to_datetime(df.FECHA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DOCUMENTO              159 non-null    object
#  1   ORGANIZACION           159 non-null    object
#  2   FECHA                  159 non-null    datetime64[ns]
#  3   TIPOFACTURA            159 non-null    object
#  4   PRODUCTO               159 non-null    object
#  5   CANTIDAD               159 non-null    float64
#  6   PRECIO                 159 non-null    float64
#  7   IMPORTEMONTRANSACCION  159 non-null    float64
#  8   MONEDA                 159 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 11.3+ KB

# %% [markdown]
# <a name="respuesta05"></a>
#
# ## **Respuesta sugerida al Punto 05 - Agrupe el DataFrame**

# %% [markdown]
# ***Organizacion como columna...***

# %%
df.groupby(by="ORGANIZACION", as_index=False).count()
# Out:
#                   ORGANIZACION  DOCUMENTO  FECHA  TIPOFACTURA  PRODUCTO  \
# 0                 Amazon Group         13     13           13        13
# 1                 Berker S.R.L          7      7            7         7
# 2                Campomas S.A.          7      7            7         7
# 3              Donadelli S.R.L          6      6            6         6
# 4                 Etigand S.A.          9      9            9         9
# 5            Ferrari Hnos S.A.          5      5            5         5
# 6                Galardon S.A.          7      7            7         7
# 7               Hernandez S.A.         14     14           14        14
# 8              Horacio Aguirre          1      1            1         1
# 9               Horizonte S.A.          6      6            6         6
# 10            Ignition S.A.C.I          7      7            7         7
# 11                 Jameson SRL          7      7            7         7
# ...

# %% [markdown]
# ***Organización como Index...***

# %%
df.groupby(by="ORGANIZACION").count()
# Out:
#                             DOCUMENTO  FECHA  TIPOFACTURA  PRODUCTO  CANTIDAD  \
# ORGANIZACION
# Amazon Group                       13     13           13        13        13
# Berker S.R.L                        7      7            7         7         7
# Campomas S.A.                       7      7            7         7         7
# Donadelli S.R.L                     6      6            6         6         6
# Etigand S.A.                        9      9            9         9         9
# Ferrari Hnos S.A.                   5      5            5         5         5
# Galardon S.A.                       7      7            7         7         7
# Hernandez S.A.                     14     14           14        14        14
# Horacio Aguirre                     1      1            1         1         1
# Horizonte S.A.                      6      6            6         6         6
# Ignition S.A.C.I                    7      7            7         7         7
# ...

# %% [markdown]
# <a name="respuesta06"></a>
#
# ## Respuesta sugerida al Punto 06 - Agrupe el DataFrame

# %% [markdown]
# ***Organizacion y Fecha como columna...***

# %%
df.groupby(by=["ORGANIZACION", "FECHA"], as_index=False).count()
# Out:
#                    ORGANIZACION      FECHA  DOCUMENTO  TIPOFACTURA  PRODUCTO  \
# 0                  Amazon Group 2018-05-10          2            2         2
# 1                  Amazon Group 2018-08-11          3            3         3
# 2                  Amazon Group 2018-09-25          1            1         1
# 3                  Amazon Group 2018-12-23          3            3         3
# 4                  Amazon Group 2019-03-21          1            1         1
# ..                          ...        ...        ...          ...       ...
# 131  Nicolasen y Asociados S.A. 2019-12-04          1            1         1
# 132               Rodrigo Vidal 2018-06-09          3            3         3
# 133               Rodrigo Vidal 2018-10-18          3            3         3
# 134            Valeria Welponer 2018-03-10          2            2         2
# 135            Valeria Welponer 2019-03-06          1            1         1
#
# ...

# %% [markdown]
# ***Organizacion y Fecha como Index...***

# %%
df.groupby(by=["ORGANIZACION", "FECHA"]).count()
# Out:
#                                        DOCUMENTO  TIPOFACTURA  PRODUCTO  \
# ORGANIZACION               FECHA
# Amazon Group               2018-05-10          2            2         2
#                            2018-08-11          3            3         3
#                            2018-09-25          1            1         1
#                            2018-12-23          3            3         3
#                            2019-03-21          1            1         1
# ...                                          ...          ...       ...
# Nicolasen y Asociados S.A. 2019-12-04          1            1         1
# Rodrigo Vidal              2018-06-09          3            3         3
#                            2018-10-18          3            3         3
# Valeria Welponer           2018-03-10          2            2         2
#                            2019-03-06          1            1         1
#
#                                        CANTIDAD  PRECIO  \
# ...
