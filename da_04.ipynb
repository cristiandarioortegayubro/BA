# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/BA/blob/main/da_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo](https://github.com/cristiandarioortegayubro/BA/blob/main/dba.png?raw=true)

# %% [markdown]
# # **Detección de Anomalías - Análisis Gráfico**

# %% [markdown]
# ## **Carga de librerías necesarias**

# %% [markdown]
# ### **Analisis de datos**

# %%
import numpy as np
import pandas as pd
from math import pi

# %% [markdown]
# ### **Graficos**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt
import plotly.express as px
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## **Obtención de los Datos**

# %% [markdown]
# ### **Generación de Datos**

# %%
ventas = np.array([18000,18000,19000,20000,
                   21000,21000,21000,22000,
                   23000,23000,23000,23000,
                   26000,27000,27000,28000,
                   30000,30000,30000,30000,
                   31000,32000,33000,34000,
                   35000,35000,36000,80000])
ventas_unique, counts = np.unique(ventas, return_counts=True)

# %% [markdown]
# ## **Análisis Grafico de una dimensión**

# %%
sizes = counts*100
colors = ['green']*len(ventas_unique)
colors[-1] = 'orange'

plt.figure(figsize = (13, 7))
plt.axhline(1, color='k', linestyle='--')
plt.scatter(ventas_unique, np.ones(len(ventas_unique)), s=sizes, color=colors)
plt.yticks([])
plt.show()

# %% [markdown]
# ## **Obtención de los Datos**

# %% [markdown]
# ### **Generación de Datos**

# %%
salario_anual_miles = np.array([16,20,15,21,19,17,33,22,31,32,56,30,22,31,30,16,2,22,23])

# %%
edades = np.array([22,22,23,23,23,23,26,27,27,28,30,30,30,30,31,32,33,34,80])

# %%
media = (salario_anual_miles).mean()
std_x = (salario_anual_miles).std()*2
media_y = (edades).mean()
std_y = (edades).std()*2

# %% [markdown]
# ## **Análisis Grafico de dos dimensiones**

# %%
colors = ['blue']*len(salario_anual_miles)

for index, x in enumerate(salario_anual_miles):
    if abs(x-media) > std_x:
        colors[index] = 'red'
        
for index, x in enumerate(edades):
    if abs(x-media_y) > std_y:
        colors[index] = 'red'

plt.figure(figsize = (13, 7))
plt.scatter(edades, salario_anual_miles, s=100, color=colors)
plt.axhline(media, color='k', linestyle='--')
plt.axvline(media_y, color='k', linestyle='--')

v=media     #y-position of the center
u=media_y    #x-position of the center
b=std_x     #radius on the y-axis
a=std_y    #radius on the x-axis

t = np.linspace(0, 2*pi, 100)
plt.plot( u+a*np.cos(t) , v+b*np.sin(t) )

plt.xlabel('Edad')
plt.ylabel('Salario Anual (miles)')
plt.show()

# %% [markdown]
# ## **Obtención de los Datos**

# %% [markdown]
# ### **Generación de Datos**

# %%
compras_mes = np.array([1,2,1,20,1,0,3,2,3,0,5,3,2,1,0,1,2,2,2])
media_z = (compras_mes).mean()
std_z = (compras_mes).std()*2

# %% [markdown]
# ## **Análisis Grafico de tres dimensiones**

# %%
fig = plt.figure(figsize = (13, 7))
ax = fig.gca(projection='3d')
for index, x in enumerate(compras_mes):
    if abs(x-media_z) > std_z:
        colors[index] = 'red'

ax.scatter(edades, salario_anual_miles, compras_mes, s=20, c=colors)
plt.xlabel('Edad')
plt.ylabel('Salario Anual (miles)')
ax.set_zlabel('Compras mensuales')

plt.show()
